# %% [markdown]
# # Third assignment

# %% [markdown]
# Create a deep neural network that predicts the expected mean temperature (average of max and min for a given day) one day, one week, and one month in advance in Budapest.
#
# Document the solution in detail (comments, readme.md) and upload it in Jupyter Notebook format. The solution should be easy to run.
# Attach the training data to a separate CSV file, and have your solution display 3 predicted values for the following days:
# * October 28
# * November 3
# * November 24
#
# I used meteorological data (daily average temperatures) from 2017.01.01 to 2020.10.25, which I downloaded from https://meteostat.net/en/place/HU-YSS8 .
#
# I built a 1D CNN, similar to that seen in exercise 7, which we used for sequential data regression. I used EarlyStopping for the training, with ModelCheckpoint to save the best model.
# I chose 30 for patience parameter, because I saw that during model fitting, the resulting val_loss metric converged slowly with many local minimums far away from each other.
# I also standardized the X_train, X_valid and X_test datasets, but not the target datasets. This way the predictions had the same unit of measurements as the original data.
# ( https://stats.stackexchange.com/questions/111467/is-it-necessary-to-scale-the-target-value-in-addition-to-scaling-features-for-re )
#
# For the forecast, I chose the following solution:
#
# The constructed CNN works by taking window_size-length data sequences (say: data points from timestamp t1 to t20 with window_size = 20), and predicts the value right after the current sequence (so t21 in this example) based on it.
# So if I take the last window_size-length sequence from the dataset as X_test, I get the predicted average temperature for the following day (October 26).
# To get forecasts for an arbitrary-long time period I append the predicted value to the end of X_test with excluding the first element to get another window_size-length sequence.
# Repeat this until the user gets the required number of predictions set in the num_of_forecast variable.
#
#
# ## Usage
#
# Set the num_of_forecast variable according to how many days you want the forecast,
# then simply run the script.

# %%
import numpy as np
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten, Conv1D, MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

num_of_forecast = 30

# I chose the following parameters for the data split, model, training,...
valid_split = 0.2
num_filter = 32
filter_length = 5
# I use two months of data for one prediction
window_size = 60

if __name__ == "__main__":
    # read in the dataset from the relevant file and
    # reshape it for later use
    dataset = []
    with open('dataset.csv') as file:
        for row in file:
            row_split = row.rstrip().split(';')
            dataset.append(float(row_split[1]))
    dataset = np.array(dataset)
    dataset = np.atleast_2d(dataset).T

    # make window_size-length sequences
    # with targets starting from the element after the first sequence
    X = np.atleast_3d(
        np.array([dataset[start:start + window_size] for start in range(0, dataset.shape[0] - window_size + 1)]))
    Y = dataset[window_size:]

    # separate the last sequence as X_test and reshape it to
    # (num_samples, window_size, num_features) dimension required by the model
    X, X_test = X[:-1], X[-1]
    X_test = X_test.reshape((1, -1, 1))

    # split the data into train and validation databases
    num_samples = X.shape[0]
    train_size = int(num_samples * (1 - valid_split))
    X_train, Y_train = X[:train_size], Y[:train_size]
    X_valid, Y_valid = X[train_size:], Y[train_size:]

    # standardize X_train, X_valid and X_test
    train_mean = np.mean(X_train)
    train_std = np.std(X_train)

    X_train = (X_train - train_mean) / train_std
    X_valid = (X_valid - train_mean) / train_std
    X_test = (X_test - train_mean) / train_std

    # create the CNN
    model = Sequential()
    model.add(Conv1D(filters=num_filter, kernel_size=filter_length, activation='relu',
                     input_shape=(window_size, 1)))
    model.add(MaxPooling1D())
    model.add(Conv1D(filters=num_filter, kernel_size=filter_length, activation='relu'))
    model.add(MaxPooling1D())
    model.add(Flatten())
    model.add(Dense(1, activation='linear'))
    model.compile(loss='mse', optimizer='adam', metrics=['mae'])

    # fit the model with EarlyStopping and ModelCheckpoint as callbacks
    patience = 30
    early_stopping = EarlyStopping(patience=patience, verbose=1)
    checkpointer = ModelCheckpoint(filepath='model.hdf5', save_best_only=True, verbose=1)

    model.fit(X_train, Y_train, epochs=500, batch_size=16, validation_data=(X_valid, Y_valid), verbose=2,
              callbacks=[early_stopping, checkpointer])

    # load the model saved by ModelCheckpoint
    model = load_model('model.hdf5')

    # forecast future temperature values (num_of_forecast = 30)
    forecasted_values = []
    for i in range(0, num_of_forecast):
        # the prediction uses the same unit of measurement as the original data,
        # so I need to standardize it again after appending it to the forecasted_values
        preds = model.predict(X_test).flatten()
        forecasted_values.append(list(preds)[0])
        X_test = X_test[:, 1:, :]
        X_test = np.append(X_test, ((preds - train_mean) / train_std)).reshape((1, -1, 1))

    print(f"\nPredicted mean temperature for october 28:\t\t{forecasted_values[2]}")
    print(f"Predicted mean temperature for november 3:\t\t{forecasted_values[8]}")
    print(f"Predicted mean temperature for november 24:\t\t{forecasted_values[-1]}")
# Out:
# Epoch 1/1000
#
# Epoch 00001: val_loss improved from inf to 36.05309, saving model to model.hdf5
# 67/67 - 0s - loss: 121.2504 - mae: 8.6392 - val_loss: 36.0531 - val_mae: 4.9044
# Epoch 2/1000
#
# Epoch 00002: val_loss improved from 36.05309 to 19.74185, saving model to model.hdf5
# 67/67 - 0s - loss: 30.2106 - mae: 4.4526 - val_loss: 19.7418 - val_mae: 3.6526
# Epoch 3/1000
#
# Epoch 00003: val_loss improved from 19.74185 to 15.23289, saving model to model.hdf5
# 67/67 - 0s - loss: 22.2331 - mae: 3.8527 - val_loss: 15.2329 - val_mae: 3.2097
# Epoch 4/1000
#
# Epoch 00004: val_loss improved from 15.23289 to 12.45829, saving model to model.hdf5
# 67/67 - 0s - loss: 16.5261 - mae: 3.3161 - val_loss: 12.4583 - val_mae: 2.8396
# Epoch 5/1000
#
# Epoch 00005: val_loss improved from 12.45829 to 11.07176, saving model to model.hdf5
# 67/67 - 0s - loss: 14.1767 - mae: 3.0664 - val_loss: 11.0718 - val_mae: 2.7447
# Epoch 6/1000
#
# Epoch 00006: val_loss improved from 11.07176 to 10.58314, saving model to model.hdf5
# 67/67 - 0s - loss: 12.9867 - mae: 2.9386 - val_loss: 10.5831 - val_mae: 2.6535
# Epoch 7/1000
#
# Epoch 00007: val_loss improved from 10.58314 to 10.52977, saving model to model.hdf5
# 67/67 - 0s - loss: 12.7329 - mae: 2.9114 - val_loss: 10.5298 - val_mae: 2.6765
# Epoch 8/1000
#
# Epoch 00008: val_loss improved from 10.52977 to 10.39097, saving model to model.hdf5
# 67/67 - 0s - loss: 12.9911 - mae: 2.9060 - val_loss: 10.3910 - val_mae: 2.6563
# Epoch 9/1000
#
# Epoch 00009: val_loss improved from 10.39097 to 10.21950, saving model to model.hdf5
# 67/67 - 0s - loss: 11.7744 - mae: 2.7886 - val_loss: 10.2195 - val_mae: 2.6244
# Epoch 10/1000
#
# Epoch 00010: val_loss improved from 10.21950 to 10.01001, saving model to model.hdf5
# 67/67 - 0s - loss: 11.3815 - mae: 2.7259 - val_loss: 10.0100 - val_mae: 2.5973
# Epoch 11/1000
#
# Epoch 00011: val_loss did not improve from 10.01001
# 67/67 - 0s - loss: 11.4786 - mae: 2.7281 - val_loss: 10.2349 - val_mae: 2.5856
# Epoch 12/1000
#
# Epoch 00012: val_loss did not improve from 10.01001
# 67/67 - 0s - loss: 10.9236 - mae: 2.6533 - val_loss: 10.1165 - val_mae: 2.6088
# Epoch 13/1000
#
# Epoch 00013: val_loss did not improve from 10.01001
# 67/67 - 0s - loss: 10.2348 - mae: 2.5786 - val_loss: 10.2748 - val_mae: 2.5930
# Epoch 14/1000
#
# Epoch 00014: val_loss did not improve from 10.01001
# 67/67 - 0s - loss: 10.0144 - mae: 2.5201 - val_loss: 10.1769 - val_mae: 2.5515
# Epoch 15/1000
#
# Epoch 00015: val_loss did not improve from 10.01001
# 67/67 - 0s - loss: 9.8163 - mae: 2.5152 - val_loss: 10.2704 - val_mae: 2.6455
# Epoch 16/1000
#
# Epoch 00016: val_loss improved from 10.01001 to 9.63356, saving model to model.hdf5
# 67/67 - 0s - loss: 9.5810 - mae: 2.4838 - val_loss: 9.6336 - val_mae: 2.4918
# Epoch 17/1000
#
# Epoch 00017: val_loss did not improve from 9.63356
# 67/67 - 0s - loss: 9.0689 - mae: 2.3955 - val_loss: 9.6852 - val_mae: 2.4805
# Epoch 18/1000
#
# Epoch 00018: val_loss improved from 9.63356 to 9.50579, saving model to model.hdf5
# 67/67 - 0s - loss: 8.9986 - mae: 2.4042 - val_loss: 9.5058 - val_mae: 2.4844
# Epoch 19/1000
#
# Epoch 00019: val_loss improved from 9.50579 to 9.32190, saving model to model.hdf5
# 67/67 - 0s - loss: 8.7442 - mae: 2.3500 - val_loss: 9.3219 - val_mae: 2.4480
# Epoch 20/1000
#
# Epoch 00020: val_loss improved from 9.32190 to 9.19374, saving model to model.hdf5
# 67/67 - 0s - loss: 8.6120 - mae: 2.3299 - val_loss: 9.1937 - val_mae: 2.4233
# Epoch 21/1000
#
# Epoch 00021: val_loss did not improve from 9.19374
# 67/67 - 0s - loss: 8.4255 - mae: 2.2960 - val_loss: 9.5447 - val_mae: 2.4446
# Epoch 22/1000
#
# Epoch 00022: val_loss did not improve from 9.19374
# 67/67 - 0s - loss: 8.1037 - mae: 2.2593 - val_loss: 9.4594 - val_mae: 2.4893
# Epoch 23/1000
#
# Epoch 00023: val_loss did not improve from 9.19374
# 67/67 - 0s - loss: 8.0270 - mae: 2.2583 - val_loss: 9.4288 - val_mae: 2.4854
# Epoch 24/1000
#
# Epoch 00024: val_loss did not improve from 9.19374
# 67/67 - 0s - loss: 8.4098 - mae: 2.3219 - val_loss: 9.5596 - val_mae: 2.4325
# Epoch 25/1000
#
# Epoch 00025: val_loss improved from 9.19374 to 8.89849, saving model to model.hdf5
# 67/67 - 0s - loss: 7.9408 - mae: 2.2314 - val_loss: 8.8985 - val_mae: 2.3865
# Epoch 26/1000
#
# Epoch 00026: val_loss did not improve from 8.89849
# 67/67 - 0s - loss: 7.7215 - mae: 2.1943 - val_loss: 9.0193 - val_mae: 2.3880
# Epoch 27/1000
#
# Epoch 00027: val_loss improved from 8.89849 to 8.70004, saving model to model.hdf5
# 67/67 - 0s - loss: 7.9142 - mae: 2.2348 - val_loss: 8.7000 - val_mae: 2.3386
# Epoch 28/1000
#
# Epoch 00028: val_loss did not improve from 8.70004
# 67/67 - 0s - loss: 7.7192 - mae: 2.1942 - val_loss: 9.6885 - val_mae: 2.4290
# Epoch 29/1000
#
# Epoch 00029: val_loss improved from 8.70004 to 8.58312, saving model to model.hdf5
# 67/67 - 0s - loss: 7.5117 - mae: 2.1686 - val_loss: 8.5831 - val_mae: 2.3458
# Epoch 30/1000
#
# Epoch 00030: val_loss improved from 8.58312 to 8.56672, saving model to model.hdf5
# 67/67 - 0s - loss: 7.4672 - mae: 2.1710 - val_loss: 8.5667 - val_mae: 2.3272
# Epoch 31/1000
#
# Epoch 00031: val_loss improved from 8.56672 to 8.51603, saving model to model.hdf5
# 67/67 - 0s - loss: 7.3417 - mae: 2.1290 - val_loss: 8.5160 - val_mae: 2.3368
# Epoch 32/1000
#
# Epoch 00032: val_loss did not improve from 8.51603
# 67/67 - 0s - loss: 7.1519 - mae: 2.1313 - val_loss: 8.7629 - val_mae: 2.3222
# Epoch 33/1000
#
# Epoch 00033: val_loss did not improve from 8.51603
# 67/67 - 0s - loss: 7.2883 - mae: 2.1366 - val_loss: 8.7688 - val_mae: 2.3878
# Epoch 34/1000
#
# Epoch 00034: val_loss did not improve from 8.51603
# 67/67 - 0s - loss: 7.2915 - mae: 2.1371 - val_loss: 8.6409 - val_mae: 2.3338
# Epoch 35/1000
#
# Epoch 00035: val_loss improved from 8.51603 to 8.19606, saving model to model.hdf5
# 67/67 - 0s - loss: 6.8653 - mae: 2.0799 - val_loss: 8.1961 - val_mae: 2.2763
# Epoch 36/1000
#
# Epoch 00036: val_loss did not improve from 8.19606
# 67/67 - 0s - loss: 6.9690 - mae: 2.0921 - val_loss: 8.6437 - val_mae: 2.3663
# Epoch 37/1000
#
# Epoch 00037: val_loss improved from 8.19606 to 8.05005, saving model to model.hdf5
# 67/67 - 0s - loss: 7.1666 - mae: 2.1394 - val_loss: 8.0500 - val_mae: 2.2479
# Epoch 38/1000
#
# Epoch 00038: val_loss improved from 8.05005 to 7.96558, saving model to model.hdf5
# 67/67 - 0s - loss: 6.8920 - mae: 2.0990 - val_loss: 7.9656 - val_mae: 2.2302
# Epoch 39/1000
#
# Epoch 00039: val_loss did not improve from 7.96558
# 67/67 - 0s - loss: 6.7959 - mae: 2.0702 - val_loss: 7.9675 - val_mae: 2.2354
# Epoch 40/1000
#
# Epoch 00040: val_loss improved from 7.96558 to 7.88135, saving model to model.hdf5
# 67/67 - 0s - loss: 6.7647 - mae: 2.0559 - val_loss: 7.8814 - val_mae: 2.2283
# Epoch 41/1000
#
# Epoch 00041: val_loss did not improve from 7.88135
# 67/67 - 0s - loss: 6.6265 - mae: 2.0297 - val_loss: 8.6795 - val_mae: 2.3075
# Epoch 42/1000
#
# Epoch 00042: val_loss did not improve from 7.88135
# 67/67 - 0s - loss: 6.8360 - mae: 2.0871 - val_loss: 7.9390 - val_mae: 2.2224
# Epoch 43/1000
#
# Epoch 00043: val_loss improved from 7.88135 to 7.83683, saving model to model.hdf5
# 67/67 - 0s - loss: 6.6876 - mae: 2.0440 - val_loss: 7.8368 - val_mae: 2.2214
# Epoch 44/1000
#
# Epoch 00044: val_loss did not improve from 7.83683
# 67/67 - 0s - loss: 6.2606 - mae: 2.0024 - val_loss: 8.1394 - val_mae: 2.2320
# Epoch 45/1000
#
# Epoch 00045: val_loss did not improve from 7.83683
# 67/67 - 0s - loss: 6.3573 - mae: 2.0071 - val_loss: 8.0317 - val_mae: 2.2569
# Epoch 46/1000
#
# Epoch 00046: val_loss did not improve from 7.83683
# 67/67 - 0s - loss: 6.4148 - mae: 2.0248 - val_loss: 8.5181 - val_mae: 2.2728
# Epoch 47/1000
#
# Epoch 00047: val_loss improved from 7.83683 to 7.63163, saving model to model.hdf5
# 67/67 - 0s - loss: 6.6084 - mae: 2.0492 - val_loss: 7.6316 - val_mae: 2.1816
# Epoch 48/1000
#
# Epoch 00048: val_loss did not improve from 7.63163
# 67/67 - 0s - loss: 6.1584 - mae: 1.9817 - val_loss: 8.0131 - val_mae: 2.2176
# Epoch 49/1000
#
# Epoch 00049: val_loss improved from 7.63163 to 7.61233, saving model to model.hdf5
# 67/67 - 0s - loss: 5.9376 - mae: 1.9394 - val_loss: 7.6123 - val_mae: 2.1778
# Epoch 50/1000
#
# Epoch 00050: val_loss improved from 7.61233 to 7.52220, saving model to model.hdf5
# 67/67 - 0s - loss: 5.9830 - mae: 1.9674 - val_loss: 7.5222 - val_mae: 2.1593
# Epoch 51/1000
#
# Epoch 00051: val_loss did not improve from 7.52220
# 67/67 - 0s - loss: 6.0814 - mae: 1.9570 - val_loss: 7.7202 - val_mae: 2.1966
# Epoch 52/1000
#
# Epoch 00052: val_loss improved from 7.52220 to 7.38051, saving model to model.hdf5
# 67/67 - 0s - loss: 5.8979 - mae: 1.9413 - val_loss: 7.3805 - val_mae: 2.1323
# Epoch 53/1000
#
# Epoch 00053: val_loss did not improve from 7.38051
# 67/67 - 0s - loss: 5.9941 - mae: 1.9468 - val_loss: 7.6053 - val_mae: 2.1813
# Epoch 54/1000
#
# Epoch 00054: val_loss did not improve from 7.38051
# 67/67 - 0s - loss: 6.0251 - mae: 1.9427 - val_loss: 7.7893 - val_mae: 2.2121
# Epoch 55/1000
#
# Epoch 00055: val_loss did not improve from 7.38051
# 67/67 - 0s - loss: 5.7609 - mae: 1.9174 - val_loss: 7.9605 - val_mae: 2.2050
# Epoch 56/1000
#
# Epoch 00056: val_loss did not improve from 7.38051
# 67/67 - 0s - loss: 6.0380 - mae: 1.9446 - val_loss: 8.4083 - val_mae: 2.2552
# Epoch 57/1000
#
# Epoch 00057: val_loss improved from 7.38051 to 7.34305, saving model to model.hdf5
# 67/67 - 0s - loss: 6.1935 - mae: 1.9767 - val_loss: 7.3431 - val_mae: 2.1348
# Epoch 58/1000
#
# Epoch 00058: val_loss improved from 7.34305 to 7.19275, saving model to model.hdf5
# 67/67 - 0s - loss: 5.7198 - mae: 1.9088 - val_loss: 7.1928 - val_mae: 2.1128
# Epoch 59/1000
#
# Epoch 00059: val_loss did not improve from 7.19275
# 67/67 - 0s - loss: 5.7186 - mae: 1.9057 - val_loss: 7.3359 - val_mae: 2.1358
# Epoch 60/1000
#
# Epoch 00060: val_loss did not improve from 7.19275
# 67/67 - 0s - loss: 5.6030 - mae: 1.8822 - val_loss: 7.2849 - val_mae: 2.1105
# Epoch 61/1000
#
# Epoch 00061: val_loss did not improve from 7.19275
# 67/67 - 0s - loss: 5.5659 - mae: 1.8751 - val_loss: 7.3973 - val_mae: 2.1498
# Epoch 62/1000
#
# Epoch 00062: val_loss did not improve from 7.19275
# 67/67 - 0s - loss: 5.5912 - mae: 1.8883 - val_loss: 7.2473 - val_mae: 2.1000
# Epoch 63/1000
#
# Epoch 00063: val_loss did not improve from 7.19275
# 67/67 - 0s - loss: 5.7636 - mae: 1.9031 - val_loss: 7.4210 - val_mae: 2.1378
# Epoch 64/1000
#
# Epoch 00064: val_loss improved from 7.19275 to 7.06272, saving model to model.hdf5
# 67/67 - 0s - loss: 5.5509 - mae: 1.8730 - val_loss: 7.0627 - val_mae: 2.0939
# Epoch 65/1000
#
# Epoch 00065: val_loss did not improve from 7.06272
# 67/67 - 0s - loss: 5.4530 - mae: 1.8467 - val_loss: 7.1282 - val_mae: 2.1081
# Epoch 66/1000
#
# Epoch 00066: val_loss did not improve from 7.06272
# 67/67 - 0s - loss: 5.5964 - mae: 1.8799 - val_loss: 7.2725 - val_mae: 2.1040
# Epoch 67/1000
#
# Epoch 00067: val_loss did not improve from 7.06272
# 67/67 - 0s - loss: 5.3241 - mae: 1.8424 - val_loss: 7.2584 - val_mae: 2.1261
# Epoch 68/1000
#
# Epoch 00068: val_loss did not improve from 7.06272
# 67/67 - 0s - loss: 5.4361 - mae: 1.8439 - val_loss: 7.0852 - val_mae: 2.0928
# Epoch 69/1000
#
# Epoch 00069: val_loss did not improve from 7.06272
# 67/67 - 0s - loss: 5.4052 - mae: 1.8556 - val_loss: 7.3827 - val_mae: 2.1260
# Epoch 70/1000
#
# Epoch 00070: val_loss improved from 7.06272 to 7.02268, saving model to model.hdf5
# 67/67 - 0s - loss: 5.2249 - mae: 1.8262 - val_loss: 7.0227 - val_mae: 2.0700
# Epoch 71/1000
#
# Epoch 00071: val_loss did not improve from 7.02268
# 67/67 - 0s - loss: 5.3189 - mae: 1.8386 - val_loss: 7.1447 - val_mae: 2.0825
# Epoch 72/1000
#
# Epoch 00072: val_loss improved from 7.02268 to 6.93913, saving model to model.hdf5
# 67/67 - 0s - loss: 5.2967 - mae: 1.8326 - val_loss: 6.9391 - val_mae: 2.0754
# Epoch 73/1000
#
# Epoch 00073: val_loss did not improve from 6.93913
# 67/67 - 0s - loss: 5.1892 - mae: 1.8191 - val_loss: 7.0198 - val_mae: 2.0950
# Epoch 74/1000
#
# Epoch 00074: val_loss improved from 6.93913 to 6.92320, saving model to model.hdf5
# 67/67 - 0s - loss: 5.1200 - mae: 1.7984 - val_loss: 6.9232 - val_mae: 2.0720
# Epoch 75/1000
#
# Epoch 00075: val_loss did not improve from 6.92320
# 67/67 - 0s - loss: 5.1261 - mae: 1.8170 - val_loss: 7.5560 - val_mae: 2.1386
# Epoch 76/1000
#
# Epoch 00076: val_loss did not improve from 6.92320
# 67/67 - 0s - loss: 4.9228 - mae: 1.7821 - val_loss: 7.2824 - val_mae: 2.1250
# Epoch 77/1000
#
# Epoch 00077: val_loss did not improve from 6.92320
# 67/67 - 0s - loss: 5.1345 - mae: 1.7857 - val_loss: 7.3560 - val_mae: 2.1348
# Epoch 78/1000
#
# Epoch 00078: val_loss improved from 6.92320 to 6.74467, saving model to model.hdf5
# 67/67 - 0s - loss: 5.0949 - mae: 1.8062 - val_loss: 6.7447 - val_mae: 2.0452
# Epoch 79/1000
#
# Epoch 00079: val_loss did not improve from 6.74467
# 67/67 - 0s - loss: 4.8916 - mae: 1.7566 - val_loss: 7.0546 - val_mae: 2.1029
# Epoch 80/1000
#
# Epoch 00080: val_loss did not improve from 6.74467
# 67/67 - 0s - loss: 5.0215 - mae: 1.7902 - val_loss: 6.9075 - val_mae: 2.0817
# Epoch 81/1000
#
# Epoch 00081: val_loss did not improve from 6.74467
# 67/67 - 0s - loss: 5.0634 - mae: 1.7855 - val_loss: 6.8302 - val_mae: 2.0703
# Epoch 82/1000
#
# Epoch 00082: val_loss did not improve from 6.74467
# 67/67 - 0s - loss: 4.7785 - mae: 1.7445 - val_loss: 7.1024 - val_mae: 2.1242
# Epoch 83/1000
#
# Epoch 00083: val_loss did not improve from 6.74467
# 67/67 - 0s - loss: 4.9521 - mae: 1.7657 - val_loss: 6.7720 - val_mae: 2.0437
# Epoch 84/1000
#
# Epoch 00084: val_loss did not improve from 6.74467
# 67/67 - 0s - loss: 4.7433 - mae: 1.7235 - val_loss: 7.0532 - val_mae: 2.0946
# Epoch 85/1000
#
# Epoch 00085: val_loss did not improve from 6.74467
# 67/67 - 0s - loss: 4.7286 - mae: 1.7261 - val_loss: 7.1153 - val_mae: 2.0977
# Epoch 86/1000
#
# Epoch 00086: val_loss did not improve from 6.74467
# 67/67 - 0s - loss: 4.8525 - mae: 1.7455 - val_loss: 7.0792 - val_mae: 2.1183
# Epoch 87/1000
#
# Epoch 00087: val_loss did not improve from 6.74467
# 67/67 - 0s - loss: 4.7382 - mae: 1.7432 - val_loss: 6.7599 - val_mae: 2.0351
# Epoch 88/1000
#
# Epoch 00088: val_loss improved from 6.74467 to 6.64868, saving model to model.hdf5
# 67/67 - 0s - loss: 4.6187 - mae: 1.7183 - val_loss: 6.6487 - val_mae: 2.0203
# Epoch 89/1000
#
# Epoch 00089: val_loss did not improve from 6.64868
# 67/67 - 0s - loss: 4.5933 - mae: 1.7016 - val_loss: 6.7144 - val_mae: 2.0375
# Epoch 90/1000
#
# Epoch 00090: val_loss did not improve from 6.64868
# 67/67 - 0s - loss: 4.9350 - mae: 1.7799 - val_loss: 7.9508 - val_mae: 2.2221
# Epoch 91/1000
#
# Epoch 00091: val_loss did not improve from 6.64868
# 67/67 - 0s - loss: 4.4872 - mae: 1.6812 - val_loss: 6.9761 - val_mae: 2.0605
# Epoch 92/1000
#
# Epoch 00092: val_loss did not improve from 6.64868
# 67/67 - 0s - loss: 4.5839 - mae: 1.6996 - val_loss: 6.7497 - val_mae: 2.0559
# Epoch 93/1000
#
# Epoch 00093: val_loss improved from 6.64868 to 6.64784, saving model to model.hdf5
# 67/67 - 1s - loss: 4.6052 - mae: 1.7170 - val_loss: 6.6478 - val_mae: 2.0250
# Epoch 94/1000
#
# Epoch 00094: val_loss did not improve from 6.64784
# 67/67 - 0s - loss: 4.7838 - mae: 1.7396 - val_loss: 7.3849 - val_mae: 2.1822
# Epoch 95/1000
#
# Epoch 00095: val_loss did not improve from 6.64784
# 67/67 - 0s - loss: 4.4655 - mae: 1.6801 - val_loss: 6.7135 - val_mae: 2.0328
# Epoch 96/1000
#
# Epoch 00096: val_loss improved from 6.64784 to 6.58590, saving model to model.hdf5
# 67/67 - 0s - loss: 4.4518 - mae: 1.6916 - val_loss: 6.5859 - val_mae: 2.0104
# Epoch 97/1000
#
# Epoch 00097: val_loss did not improve from 6.58590
# 67/67 - 0s - loss: 4.5424 - mae: 1.7148 - val_loss: 6.6482 - val_mae: 2.0248
# Epoch 98/1000
#
# Epoch 00098: val_loss did not improve from 6.58590
# 67/67 - 0s - loss: 4.3210 - mae: 1.6571 - val_loss: 7.1828 - val_mae: 2.1122
# Epoch 99/1000
#
# Epoch 00099: val_loss did not improve from 6.58590
# 67/67 - 0s - loss: 4.7090 - mae: 1.7153 - val_loss: 6.6125 - val_mae: 2.0035
# Epoch 100/1000
#
# Epoch 00100: val_loss did not improve from 6.58590
# 67/67 - 0s - loss: 4.3402 - mae: 1.6568 - val_loss: 6.8238 - val_mae: 2.0638
# Epoch 101/1000
#
# Epoch 00101: val_loss did not improve from 6.58590
# 67/67 - 0s - loss: 4.2326 - mae: 1.6429 - val_loss: 6.7012 - val_mae: 2.0389
# Epoch 102/1000
#
# Epoch 00102: val_loss did not improve from 6.58590
# 67/67 - 0s - loss: 4.2137 - mae: 1.6329 - val_loss: 6.7672 - val_mae: 2.0352
# Epoch 103/1000
#
# Epoch 00103: val_loss improved from 6.58590 to 6.53948, saving model to model.hdf5
# 67/67 - 0s - loss: 4.3149 - mae: 1.6462 - val_loss: 6.5395 - val_mae: 2.0013
# Epoch 104/1000
#
# Epoch 00104: val_loss improved from 6.53948 to 6.52906, saving model to model.hdf5
# 67/67 - 0s - loss: 4.2992 - mae: 1.6391 - val_loss: 6.5291 - val_mae: 1.9971
# Epoch 105/1000
#
# Epoch 00105: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 4.1033 - mae: 1.6156 - val_loss: 6.6735 - val_mae: 2.0340
# Epoch 106/1000
#
# Epoch 00106: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 4.1957 - mae: 1.6335 - val_loss: 6.6263 - val_mae: 2.0331
# Epoch 107/1000
#
# Epoch 00107: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 4.1248 - mae: 1.6072 - val_loss: 7.0760 - val_mae: 2.0757
# Epoch 108/1000
#
# Epoch 00108: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 4.0877 - mae: 1.6152 - val_loss: 6.6763 - val_mae: 2.0055
# Epoch 109/1000
#
# Epoch 00109: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 4.3306 - mae: 1.6451 - val_loss: 7.0466 - val_mae: 2.1123
# Epoch 110/1000
#
# Epoch 00110: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 4.0215 - mae: 1.6021 - val_loss: 7.1849 - val_mae: 2.1454
# Epoch 111/1000
#
# Epoch 00111: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 4.1049 - mae: 1.6112 - val_loss: 6.6980 - val_mae: 2.0492
# Epoch 112/1000
#
# Epoch 00112: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.9877 - mae: 1.5873 - val_loss: 6.9741 - val_mae: 2.1017
# Epoch 113/1000
#
# Epoch 00113: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.9330 - mae: 1.5817 - val_loss: 6.6526 - val_mae: 2.0436
# Epoch 114/1000
#
# Epoch 00114: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.9228 - mae: 1.5805 - val_loss: 6.7084 - val_mae: 2.0451
# Epoch 115/1000
#
# Epoch 00115: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 4.1381 - mae: 1.6365 - val_loss: 6.9328 - val_mae: 2.0936
# Epoch 116/1000
#
# Epoch 00116: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 4.3629 - mae: 1.6489 - val_loss: 6.8449 - val_mae: 2.0663
# Epoch 117/1000
#
# Epoch 00117: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 4.0127 - mae: 1.5907 - val_loss: 6.6386 - val_mae: 2.0358
# Epoch 118/1000
#
# Epoch 00118: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.8515 - mae: 1.5626 - val_loss: 6.5712 - val_mae: 1.9988
# Epoch 119/1000
#
# Epoch 00119: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.9551 - mae: 1.6046 - val_loss: 6.8131 - val_mae: 2.0473
# Epoch 120/1000
#
# Epoch 00120: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.8597 - mae: 1.5710 - val_loss: 6.8592 - val_mae: 2.0473
# Epoch 121/1000
#
# Epoch 00121: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.8628 - mae: 1.5570 - val_loss: 8.5586 - val_mae: 2.4008
# Epoch 122/1000
#
# Epoch 00122: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.9709 - mae: 1.5946 - val_loss: 6.5864 - val_mae: 2.0307
# Epoch 123/1000
#
# Epoch 00123: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.7923 - mae: 1.5656 - val_loss: 6.7919 - val_mae: 2.0274
# Epoch 124/1000
#
# Epoch 00124: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.8605 - mae: 1.5538 - val_loss: 6.6902 - val_mae: 2.0225
# Epoch 125/1000
#
# Epoch 00125: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.8172 - mae: 1.5533 - val_loss: 6.6073 - val_mae: 2.0253
# Epoch 126/1000
#
# Epoch 00126: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.8314 - mae: 1.5603 - val_loss: 6.8082 - val_mae: 2.0904
# Epoch 127/1000
#
# Epoch 00127: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.7976 - mae: 1.5611 - val_loss: 7.2725 - val_mae: 2.1780
# Epoch 128/1000
#
# Epoch 00128: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.7389 - mae: 1.5453 - val_loss: 6.8545 - val_mae: 2.0761
# Epoch 129/1000
#
# Epoch 00129: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.7271 - mae: 1.5456 - val_loss: 6.8549 - val_mae: 2.0813
# Epoch 130/1000
#
# Epoch 00130: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.6543 - mae: 1.5252 - val_loss: 6.8012 - val_mae: 2.0654
# Epoch 131/1000
#
# Epoch 00131: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.6222 - mae: 1.5164 - val_loss: 7.1696 - val_mae: 2.1072
# Epoch 132/1000
#
# Epoch 00132: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.6484 - mae: 1.5122 - val_loss: 6.8474 - val_mae: 2.0734
# Epoch 133/1000
#
# Epoch 00133: val_loss did not improve from 6.52906
# 67/67 - 0s - loss: 3.6747 - mae: 1.5232 - val_loss: 6.8854 - val_mae: 2.0429
# Epoch 134/1000
#
# Epoch 00134: val_loss improved from 6.52906 to 6.48578, saving model to model.hdf5
# 67/67 - 0s - loss: 3.8578 - mae: 1.5645 - val_loss: 6.4858 - val_mae: 1.9963
# Epoch 135/1000
#
# Epoch 00135: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.5554 - mae: 1.4969 - val_loss: 7.0065 - val_mae: 2.1291
# Epoch 136/1000
#
# Epoch 00136: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.5412 - mae: 1.5022 - val_loss: 6.6700 - val_mae: 2.0448
# Epoch 137/1000
#
# Epoch 00137: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.5066 - mae: 1.4944 - val_loss: 6.7525 - val_mae: 2.0737
# Epoch 138/1000
#
# Epoch 00138: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.4331 - mae: 1.4808 - val_loss: 6.5453 - val_mae: 2.0200
# Epoch 139/1000
#
# Epoch 00139: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.4384 - mae: 1.4757 - val_loss: 6.9636 - val_mae: 2.0464
# Epoch 140/1000
#
# Epoch 00140: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.3925 - mae: 1.4694 - val_loss: 6.6882 - val_mae: 2.0232
# Epoch 141/1000
#
# Epoch 00141: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.3732 - mae: 1.4734 - val_loss: 7.2136 - val_mae: 2.1726
# Epoch 142/1000
#
# Epoch 00142: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.5596 - mae: 1.5040 - val_loss: 6.8576 - val_mae: 2.1021
# Epoch 143/1000
#
# Epoch 00143: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.4068 - mae: 1.4736 - val_loss: 6.6504 - val_mae: 2.0670
# Epoch 144/1000
#
# Epoch 00144: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.5020 - mae: 1.4977 - val_loss: 7.1771 - val_mae: 2.0782
# Epoch 145/1000
#
# Epoch 00145: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.3750 - mae: 1.4618 - val_loss: 6.6554 - val_mae: 2.0522
# Epoch 146/1000
#
# Epoch 00146: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.3323 - mae: 1.4590 - val_loss: 7.3270 - val_mae: 2.1238
# Epoch 147/1000
#
# Epoch 00147: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.3027 - mae: 1.4488 - val_loss: 6.9941 - val_mae: 2.1347
# Epoch 148/1000
#
# Epoch 00148: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.3492 - mae: 1.4617 - val_loss: 6.5007 - val_mae: 2.0018
# Epoch 149/1000
#
# Epoch 00149: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.1956 - mae: 1.4193 - val_loss: 6.5306 - val_mae: 2.0110
# Epoch 150/1000
#
# Epoch 00150: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.1583 - mae: 1.4207 - val_loss: 6.8693 - val_mae: 2.1234
# Epoch 151/1000
#
# Epoch 00151: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.2153 - mae: 1.4401 - val_loss: 7.1338 - val_mae: 2.0853
# Epoch 152/1000
#
# Epoch 00152: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.2448 - mae: 1.4355 - val_loss: 7.0870 - val_mae: 2.0737
# Epoch 153/1000
#
# Epoch 00153: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.1835 - mae: 1.4306 - val_loss: 6.6483 - val_mae: 2.0517
# Epoch 154/1000
#
# Epoch 00154: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.1900 - mae: 1.4313 - val_loss: 7.2107 - val_mae: 2.1420
# Epoch 155/1000
#
# Epoch 00155: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.0961 - mae: 1.3870 - val_loss: 6.9175 - val_mae: 2.0468
# Epoch 156/1000
#
# Epoch 00156: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.3147 - mae: 1.4666 - val_loss: 6.8288 - val_mae: 2.0773
# Epoch 157/1000
#
# Epoch 00157: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.3350 - mae: 1.4453 - val_loss: 6.8706 - val_mae: 2.1117
# Epoch 158/1000
#
# Epoch 00158: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.1024 - mae: 1.3959 - val_loss: 7.2106 - val_mae: 2.1075
# Epoch 159/1000
#
# Epoch 00159: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.0821 - mae: 1.3889 - val_loss: 6.7310 - val_mae: 2.0730
# Epoch 160/1000
#
# Epoch 00160: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.0613 - mae: 1.3890 - val_loss: 7.0348 - val_mae: 2.1546
# Epoch 161/1000
#
# Epoch 00161: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 2.9839 - mae: 1.3843 - val_loss: 7.6197 - val_mae: 2.1617
# Epoch 162/1000
#
# Epoch 00162: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.0267 - mae: 1.3883 - val_loss: 6.8433 - val_mae: 2.1186
# Epoch 163/1000
#
# Epoch 00163: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 2.9246 - mae: 1.3646 - val_loss: 6.9476 - val_mae: 2.0966
# Epoch 164/1000
#
# Epoch 00164: val_loss did not improve from 6.48578
# 67/67 - 0s - loss: 3.0615 - mae: 1.4005 - val_loss: 6.9235 - val_mae: 2.0533
# Epoch 00164: early stopping
#
# Predicted mean temperature for october 28:		11.407468795776367
# Predicted mean temperature for november 3:		13.266011238098145
# Predicted mean temperature for november 24:		10.781996726989746
